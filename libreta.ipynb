# %%
2+2
# Out:
# 4

# %%
# !pip install networkx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 13.7 MB/s  0:00:00
# ...

# %%
import networkx as nx
import matplotlib as plt

# %%
g=nx.Graph()

# %%
g.add_edges_from([(0,1),(1,2),(1,4)])

# %%
nx.draw(g,with_labels=True)
